# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"E:\Downloads\netflix_titles.csv\netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# How can you view the first 10 rows of the dataset?

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# How can you get column names and data types?

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# How many rows and columns are in the dataset?

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# How do you check for missing values in all columns?

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# How do you count the number of missing values in the 'director' column?

# %%
df['director'].isnull().sum()
# Out:
# 2634

# %% [markdown]
# How do you get the unique values from the 'type' column?

# %%
df['type'].unique
# Out:
# <bound method Series.unique of 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object>

# %% [markdown]
# How do you count how many Movies vs TV Shows are in the dataset?

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# How can you filter only the rows where type == 'Movie'?

# %%
df[df['type']=='Movie']
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# How can you display the top 5 rows sorted by 'release_year'?

# %%
df.sort_values('release_year',ascending=True).head(5)
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
#
#                          director                       cast        country  \
# 4250                          NaN                        NaN            NaN
# 7790                  Frank Capra                        NaN  United States
# 8205                    John Ford  Henry Fonda, Jane Darwell  United States
# 8660                    John Ford                        NaN  United States
# 8739  Frank Capra, Anatole Litvak                        NaN  United States
#
#              date_added  release_year rating  duration  \
# ...

# %% [markdown]
# How can you find all rows where country is 'India'?

# %%
df[df['country']== 'India']
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %% [markdown]
# 🔸 20 Scenario-Based Pandas Questions (Beginner) Filter all movies that were released after 2015.
#
# Find all shows added in the year 2018.

# %%
df[(df['release_year']==2018) & (df['type']=='Movie')]
# Out:
#      show_id   type                                              title  \
# 73       s74  Movie                                       King of Boys
# 94       s95  Movie                                          Show Dogs
# 96       s97  Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 107     s108  Movie                                   A Champion Heart
# 157     s158  Movie                                           Level 16
# ...      ...    ...                                                ...
# 8706   s8707  Movie                                     We the Animals
# 8724   s8725  Movie                                 What Still Remains
# 8732   s8733  Movie                                      White Chamber
# 8743   s8744  Movie                                           Wildlife
# 8774   s8775  Movie                                          يوم الدين
#
#                 director                                               cast  \
# ...

# %% [markdown]
# Create a column year_added extracted from date_added.

# %% [markdown]
# List the top 5 countries by number of shows.

# %% [markdown]
# Group the data by 'type' and count how many shows per type.

# %%
df.groupby('type').sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19296\3932782151.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('type').sum()
#          release_year
# type
# Movie        12342448
# TV Show       5396437

# %% [markdown]
# Find the number of shows per rating (TV-MA, PG, etc.)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# Create a column 'is_movie' that’s True if type == 'Movie'.

# %% [markdown]
# How many shows have missing 'director' values?

# %% [markdown]
# Sort the dataset by 'release_year' in descending order.

# %% [markdown]
# Create a new column 'title_length' = length of the title string.

# %% [markdown]
# Filter shows where the title contains the word 'Love'.

# %% [markdown]
# Replace all missing values in 'country' with 'Unknown'.

# %% [markdown]
# Create a subset with only columns: title, type, release_year, country.

# %% [markdown]
# Find the most frequent genre in the 'listed_in' column.

# %% [markdown]
# Find all shows where director is 'Christopher Nolan'.

# %% [markdown]
# What is the most common rating for Movies?

# %% [markdown]
# Which month had the most shows added?

# %% [markdown]
# What’s the average release year of shows in the dataset?

# %% [markdown]
# Drop all rows where 'title' is missing.

# %% [markdown]
# Filter for all Indian TV Shows added after 2019.
